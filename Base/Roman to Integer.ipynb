# %% [markdown]
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# For example, 2 is written as II in Roman numeral, just two ones added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# I can be placed before V (5) and X (10) to make 4 and 9.
# X can be placed before L (50) and C (100) to make 40 and 90.
# C can be placed before D (500) and M (1000) to make 400 and 900.
# Given a roman numeral, convert it to an integer.

# %%
def roman_to_integer(s):
    list_s = list(s)
    roman_characters = ['I', 'V', 'X', 'L', 'C', 'D', 'M']
    roman_numerals = [1, 5, 10, 50, 100, 500, 1000]
    character_numeral = {}
    for i in range(len(roman_characters)):
        character_numeral[roman_characters[i]] = roman_numerals[i]
    
    number = []

    for item in list_s:
        number.append(character_numeral[item])
    
    #print("This is number",number)
    number_correct =[]

    idx = 0
    while idx < len(number)-1:
        if number[idx] < number[idx+1]:
            subtract = int(number[idx+1]) - int(number[idx])
            #print(subtract)
            idx += 2
            number_correct.append(subtract)
        else:
            idx += 1
            number_correct.append(number[idx])

    if idx == len(number) - 1:
        number_correct.append(number[idx])

    # it need to be that way because idx is incremented before the append, so the last number is ALWAYS skipped
    # <= also do not work because idx is incremented by 1 
            
    #print(number_correct)
    return sum(number_correct)

s = "III"

roman_to_integer(s)
# Out:
# 3

# %%
roman_characters = ['I', 'V', 'X', 'L', 'C', 'D', 'M']
roman_numerals = [1, 5, 10, 50, 100, 500, 1000]
character_numeral = {}
for i in range(len(roman_characters)):
    character_numeral[roman_characters[i]] = roman_numerals[i]

number = []
for item in list_s:
number.append(character_numeral[item])

print(character_numeral["I"])
# Out:
# 1
