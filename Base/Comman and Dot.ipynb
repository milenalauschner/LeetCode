# %%
# This is a teapot, not a Coffee pot. Please take care.
# This is a teapotcomma not a Coffe potdot Please take caredot

phrase1 = "This is a teapot, not a Coffee pot. Please take care."

def modification (phrase):
    phrase = phrase.replace(",", "comma").replace(".", "dot")
    return phrase

modification(phrase1)
# Out:
# 'This is a teapotcomma not a Coffee potdot Please take caredot'

# %%
phrase1 = "This is a teapot, not a Coffee pot. Please take care."

def modification (phrase):
    phrase = phrase.split()

    modify_words = []
    
    for word in phrase:
        comman_dot_string = ",."
        if word[-1] in comman_dot_string:
            if word[-1] == ",":
                word = word[0:len(word)-1] + "comma"
            else:
                word = word[0:len(word)-1] +"dot"
        print(word)
        modify_words.append(word)
    return ' '.join(modify_words)

modification(phrase1)
# Out:
# This
# is
# a
# teapotcomma
# not
# a
# Coffee
# potdot
# Please
# take
# caredot
# 'This is a teapotcomma not a Coffee potdot Please take caredot'

# %%
phrase1 = "This is a teapot, not a Coffee pot. Please take care."

def modification (phrase):
    phrase = list(phrase)

    modify_words = []
    Dict_symbols = {",":"comma", ".":"dot"}
    for word in phrase:
        comman_dot_string = ",."
        if word[-1] in comman_dot_string:
            word = word[0:len(word)-1] + Dict_symbols[word[-1]]  
            # if word[-1] == ",":
            #     word = word[0:len(word)-1] + Dict_symbols[","]
            # else:
            #     word = word[0:len(word)-1] + Dict_symbols["."]
        #print(word)
        modify_words.append(word)
    return ''.join(modify_words)

modification(phrase1)
# Out:
# 'This is a teapotcomma not a Coffee potdot Please take caredot'

# %%
Dict_symbols = {",":"comma", ".":"dot"}
x = Dict_symbols[","]
x
# Out:
# 'comma'
