# %% [markdown]
# Given an unsorted array of integers nums, return the length of the longest consecutive elements sequence.
#
# You must write an algorithm that runs in O(n) time.
#
#
#
# Example 1:
#
# Input: nums = [100,4,200,1,3,2]
# Output: 4
# Explanation: The longest consecutive elements sequence is [1, 2, 3, 4]. Therefore its length is 4.
# Example 2:
#
# Input: nums = [0,3,7,2,5,8,4,6,0,1]
# Output: 9
# Example 3:
#
# Input: nums = [1,0,1,2]
# Output: 3

# %%
nums = [100, 4, 200, 1, 3, 2]

def longestConsecutiveSequence(nums):
    num_set = set(nums)
    longest_streak = 0
    print("This is the set of numbers:", num_set)
    for num in num_set:
        if num - 1 not in num_set:  # Check if it's the start of a sequence
            print(num-1)
            current_num = num
            current_streak = 1
            print("Starting new sequence at:", current_num)
            while current_num + 1 in num_set:
                current_num += 1
                current_streak += 1
            print("Current streak:", current_streak)    
            print("Longest streak so far:", longest_streak)

            longest_streak = max(longest_streak, current_streak)

    return longest_streak

print(longestConsecutiveSequence(nums))
# Out:
# This is the set of numbers: {1, 2, 3, 100, 4, 200}
# 0
# Starting new sequence at: 1
# Current streak: 4
# Longest streak so far: 0
# 99
# Starting new sequence at: 100
# Current streak: 1
# Longest streak so far: 4
# 199
# Starting new sequence at: 200
# Current streak: 1
# Longest streak so far: 4
# 4
