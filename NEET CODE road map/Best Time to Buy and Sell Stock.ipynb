# %% [markdown]
# You are given an integer array prices where prices[i] is the price of NeetCoin on the ith day.
#
# You may choose a single day to buy one NeetCoin and choose a different day in the future to sell it.
#
# Return the maximum profit you can achieve. You may choose to not make any transactions, in which case the profit would be 0.
#
# Example 1:
#
# Input: prices = [10,1,5,6,7,1]
#
# Output: 6
# Explanation: Buy prices[1] and sell prices[4], profit = 7 - 1 = 6.
#
# Example 2:
#
# Input: prices = [10,8,7,5,2]
#
# Output: 0
# Explanation: No profitable transactions can be made, thus the max profit is 0.

# %% [markdown]
# ## Brute Force
#
# Time complexity: O(n 2)
# Space complexity: O(1)

# %%
def maxProfit(prices) -> int:
    res = 0
    for i in range(len(prices)):
        buy = prices[i]
        print("this is buy", buy)
        for j in range(i + 1, len(prices)):
            sell  = prices[j]
            print("This is sell:", sell)
            print(res)
            res = max(res, sell - buy)
            print("This is res:",res)
    return res


prices = [2,4,6]

maxProfit(prices)
# Out:
# this is buy 2
# This is sell: 4
# 0
# This is res: 2
# This is sell: 6
# 2
# This is res: 4
# this is buy 4
# This is sell: 6
# 4
# This is res: 4
# this is buy 6
# 4

# %% [markdown]
# ## Two Pointer
#
# Time O(n)
# Space O(1)

# %%
def maxProfit(prices) -> int:
    left, right = 0, 1
    maxP = 0
    while right < len(prices):
        if prices[left] < prices[right]:
            profit = prices[right] - prices[left]
            maxP = max(maxP, profit)
        else:
            left = right #resets the "buy day" to the current "sell day" when a better (cheaper) buying price is found.
            # prices[right] <= prices[left] → it's better to buy at righ
        right += 1
    return maxP

prices = [2,6,4]

maxProfit(prices)
# Out:
# 4

# %% [markdown]
# prices = [7, 1, 5, 3, 6, 4]
# At first:
# left = 0 (price = 7), right = 1 (price = 1) → 1 < 7 → update left = right
#
# Now:
# left = 1 (price = 1), right = 2 (price = 5) → profit = 4
#
# Keep going...

# %% [markdown]
# ## Dynamic Programming
#
# Time O(n)
# Space O(1)

# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        maxP = 0
        minBuy = prices[0]

        for sell in prices:
            maxP = max(maxP, sell - minBuy)
            minBuy = min(minBuy, sell)
        return maxP
